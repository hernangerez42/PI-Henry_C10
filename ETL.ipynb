# %%
#Importamos el dataset brindado!
import pandas as pd
import json
import re 
movies = pd.read_csv('Dataset/movies_dataset.csv')
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\3477437770.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('Dataset/movies_dataset.csv')

# %%
def extraer_datos(df, columna):
    # Función para extraer los valores de una cadena, lista o diccionario
    def extraer_valores(valor):
        if isinstance(valor, str):
            # Si es una cadena, extraer los valores con la expresión regular
            pattern = r"'name': '([^']*)'"
            coincidencias = re.findall(pattern, valor)
            return coincidencias
        elif isinstance(valor, list):
            # Si es una lista, extraer los valores de cada elemento de la lista
            valores = []
            for elemento in valor:
                if 'name' in elemento:
                    valores.append(elemento['name'])
            return valores
        elif isinstance(valor, dict):
            # Si es un diccionario, extraer los valores de la clave 'name'
            if 'name' in valor:
                return valor['name']
        return None
    
    # Aplicar la función a la columna y sobrescribir la columna
    df[columna] = df[columna].apply(extraer_valores)
    
    return df

# %%
#mostrar todas las columnas del dataset
pd.set_option('display.max_columns', None)

# %%
movies.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
#
#                              production_companies  \
# 0  [{'name': 'Pixar Animation Studios', 'id': 3}]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
#
#        revenue  runtime                          spoken_languages    status  \
# ...

# %%
extraer_datos(movies, 'belongs_to_collection')
extraer_datos(movies, 'genres')
extraer_datos(movies, 'production_companies')
extraer_datos(movies, 'production_countries')
extraer_datos(movies, 'spoken_languages')
# Out:
#        adult             belongs_to_collection    budget  \
# 0      False            [Toy Story Collection]  30000000
# 1      False                              None  65000000
# 2      False       [Grumpy Old Men Collection]         0
# 3      False                              None  16000000
# 4      False  [Father of the Bride Collection]         0
# ...      ...                               ...       ...
# 45461  False                              None         0
# 45462  False                              None         0
# 45463  False                              None         0
# 45464  False                              None         0
# 45465  False                              None         0
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# ...

# %%
movies.head(1)
# Out:
#    adult   belongs_to_collection    budget                       genres  \
# 0  False  [Toy Story Collection]  30000000  [Animation, Comedy, Family]
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
#
#   popularity                       poster_path       production_companies  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  [Pixar Animation Studios]
#
#          production_countries release_date      revenue  runtime  \
# 0  [United States of America]   1995-10-30  373554033.0     81.0
#
#   spoken_languages    status tagline      title  video  vote_average  \
# 0        [English]  Released     NaN  Toy Story  False           7.7
#
#    vote_count
# 0      5415.0

# %%
#Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0
movies['revenue'] = movies['revenue'].fillna(0)
movies['budget'] = movies['budget'].fillna(0)

# %%
#contamos los valores nulos de las columnas revenue y budget
movies.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      0
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
#Los valores nulos del campo release date deben eliminarse.
movies = movies.dropna(subset=['release_date'])

# %%
#contamos los valores nulos de release date
movies.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40888
# budget                       0
# genres                       0
# homepage                 37610
# id                           0
# imdb_id                     14
# original_language           11
# original_title               0
# overview                   941
# popularity                   2
# poster_path                339
# production_companies         0
# production_countries         0
# release_date                 0
# revenue                      0
# runtime                    249
# spoken_languages             3
# status                      83
# tagline                  24981
# title                        3
# video                        3
# vote_average                 3
# vote_count                   3
# dtype: int64

# %%
#De haber fechas, deberán tener el formato AAAA-mm-dd.
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\3597400814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')

# %%
#crear la columna release_year donde extraerán el año de la fecha de estreno.
movies['release_year'] = movies['release_date'].dt.year
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\797629494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['release_year'] = movies['release_date'].dt.year

# %%
movies.head(1)
# Out:
#    adult   belongs_to_collection    budget                       genres  \
# 0  False  [Toy Story Collection]  30000000  [Animation, Comedy, Family]
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
#
#   popularity                       poster_path       production_companies  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  [Pixar Animation Studios]
#
#          production_countries release_date      revenue  runtime  \
# 0  [United States of America]   1995-10-30  373554033.0     81.0
#
#   spoken_languages    status tagline      title  video  vote_average  \
# 0        [English]  Released     NaN  Toy Story  False           7.7
#
#    vote_count  release_year
# 0      5415.0        1995.0

# %%
#cambiamos el tipo de la columna renueve a int
movies['revenue'] = movies['revenue'].astype(int)
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\2633477072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['revenue'] = movies['revenue'].astype(int)

# %%
#remplacer los valores nan de la columna revenue por 0
movies['revenue'] = movies['revenue'].fillna(0)
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\1921384664.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['revenue'] = movies['revenue'].fillna(0)

# %%
# Reemplazar los valores no numéricos por NaN en la columna 'budget'
movies['budget'] = pd.to_numeric(movies['budget'], errors='coerce')
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\783883451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['budget'] = pd.to_numeric(movies['budget'], errors='coerce')

# %%
#cambiamos los valores nulos de la columna budget por 0
movies['budget'] = movies['budget'].fillna(0)
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\106303938.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['budget'] = movies['budget'].fillna(0)

# %%
#cambiamos el tipo de la columna budget a int
movies['budget'] = movies['budget'].astype(int)
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\2878116484.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['budget'] = movies['budget'].astype(int)

# %%
movies.dtypes
# Out:
# adult                            object
# belongs_to_collection            object
# budget                            int32
# genres                           object
# homepage                         object
# id                               object
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                       object
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                           int32
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                            object
# vote_average                    float64
# ...

# %%
#Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, dividiendo estas dos últimas revenue / budget
movies['return'] = movies['revenue'] / movies['budget']
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\2336372906.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['return'] = movies['revenue'] / movies['budget']

# %%
movies['return'] = movies['return'].fillna(0)
# Out:
# C:\Users\Pochito\AppData\Local\Temp\ipykernel_7208\2974251122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['return'] = movies['return'].fillna(0)

# %%
#Eliminar las columnas que no serán utilizadas, video,imdb_id,adult,original_title,vote_count,poster_path y homepage.
movies = movies.drop(['video','imdb_id','adult','original_title','vote_count','poster_path','homepage'], axis=1)

# %%
movies.shape
# Out:
# (45379, 19)

# %%
movies.head(10)
# Out:
#               belongs_to_collection    budget  \
# 0            [Toy Story Collection]  30000000
# 1                              None  65000000
# 2       [Grumpy Old Men Collection]         0
# 3                              None  16000000
# 4  [Father of the Bride Collection]         0
# 5                              None  60000000
# 6                              None  58000000
# 7                              None         0
# 8                              None  35000000
# 9           [James Bond Collection]  58000000
#
#                                genres     id original_language  \
# 0         [Animation, Comedy, Family]    862                en
# 1        [Adventure, Fantasy, Family]   8844                en
# 2                   [Romance, Comedy]  15602                en
# 3            [Comedy, Drama, Romance]  31357                en
# 4                            [Comedy]  11862                en
# 5    [Action, Crime, Drama, Thriller]    949                en
# ...

# %%
#cramos la columna release_month donde extraerán el mes de la fecha de estreno.
movies['release_month'] = movies['release_date'].dt.month

# %%
#cremos la columna release_day donde extraerán el dia de la fecha de estreno.
movies['release_day'] = movies['release_date'].dt.day

# %%
#creamos una colunma que obtenga el dia historicamente de la columna release_date
movies['release_dayofweek'] = movies['release_date'].dt.dayofweek

# %%
movies.head(3)
# Out:
#          belongs_to_collection    budget                        genres     id  \
# 0       [Toy Story Collection]  30000000   [Animation, Comedy, Family]    862
# 1                         None  65000000  [Adventure, Fantasy, Family]   8844
# 2  [Grumpy Old Men Collection]         0             [Romance, Comedy]  15602
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
#
#   popularity                               production_companies  \
# 0  21.946943                          [Pixar Animation Studios]
# 1  17.015539  [TriStar Pictures, Teitler Film, Interscope Co...
# 2    11.7129                     [Warner Bros., Lancaster Gate]
#
#          production_countries release_date    revenue  runtime  \
# ...

# %%
#eliminamos valores nulos de la columna title
movies = movies.dropna(subset=['title'])
# Out:
#     belongs_to_collection    budget                       genres   id  \
# 0  [Toy Story Collection]  30000000  [Animation, Comedy, Family]  862
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
#
#   popularity       production_companies        production_countries  \
# 0  21.946943  [Pixar Animation Studios]  [United States of America]
#
#   release_date    revenue  runtime spoken_languages    status tagline  \
# 0   1995-10-30  373554033     81.0        [English]  Released     NaN
#
#        title  vote_average  release_year     return  release_month  \
# 0  Toy Story           7.7        1995.0  12.451801           10.0
#
#    release_day  release_dayofweek
# 0         30.0                0.0

# %%
movies.isnull().sum()

# %%
#convertimos todo el dataframe en minusculas para poder hacer busquedas
movies = movies.apply(lambda x: x.astype(str).str.lower())

# %%
def eliminar_corchetes_comillas(df, columna):
    # Función para eliminar los corchetes y comillas de una columna
    df[columna] = df[columna].apply(lambda x: str(x).replace('[', '').replace(']', '').replace('"', '').replace("'", ""))
    return df

# %%
eliminar_corchetes_comillas(movies, 'belongs_to_collection')
eliminar_corchetes_comillas(movies, 'genres')
eliminar_corchetes_comillas(movies, 'production_companies')
eliminar_corchetes_comillas(movies, 'production_countries')
eliminar_corchetes_comillas(movies, 'spoken_languages')
# Out:
#                 belongs_to_collection    budget                      genres  \
# 0                toy story collection  30000000   animation, comedy, family
# 1                                none  65000000  adventure, fantasy, family
# 2           grumpy old men collection         0             romance, comedy
# 3                                none  16000000      comedy, drama, romance
# 4      father of the bride collection         0                      comedy
# ...                               ...       ...                         ...
# 45460                            none         0      drama, action, romance
# 45462                            none         0                       drama
# 45463                            none         0     action, drama, thriller
# 45464                            none         0
# 45465                            none         0
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# ...

# %%
movies.head(1)
# Out:
#   belongs_to_collection    budget                     genres   id  \
# 0  toy story collection  30000000  animation, comedy, family  862
#
#   original_language                                           overview  \
# 0                en  led by woody, andy's toys live happily in his ...
#
#   popularity     production_companies      production_countries release_date  \
# 0  21.946943  pixar animation studios  united states of america   1995-10-30
#
#      revenue runtime spoken_languages    status tagline      title  \
# 0  373554033    81.0          english  released     nan  toy story
#
#   vote_average release_year      return release_month release_day  \
# 0          7.7       1995.0  12.4518011          10.0        30.0
#
#   release_dayofweek
# 0               0.0

# %%
#cambiamos el tipo de datos a float
movies['revenue'] = movies['revenue'].astype(float)
movies['budget'] = movies['budget'].astype(float)

# %%
movies.dtypes
# Out:
# belongs_to_collection     object
# budget                   float64
# genres                    object
# id                        object
# original_language         object
# overview                  object
# popularity                object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                   object
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# vote_average              object
# release_year              object
# return                    object
# release_month             object
# release_day               object
# release_dayofweek         object
# dtype: object

# %%
#guardamos el nuevo dataset
movies.to_csv('Dataset/movies_dataset_trabajado.csv', index=False)

# %%
movies['title'].isnull().sum()
# Out:
# 0
